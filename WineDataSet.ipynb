# %%
import numpy as np #statistical 
import pandas as pd #data frame numbers . head/tail 
from scipy import stats  
import matplotlib.pyplot as plt 
import seaborn as sns #visualisation graphs and plots
#import matplotlib as plt

# %%
red_wine = pd.read_csv("wine+quality\winequality-red.csv", sep= ';', delimiter=None) 
#wine_red = pd.read_csv("C:\Users\lmyhe\Desktop\Code_Academy\Module_1\Project_2\Sprint 1\wine+quality\winequality-red.csv") 
#doesnt work. some issue in the first part of the pathway. possibly because of the lmy part.

# %%
red_wine
#fix the view like in one of our first exercises
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
red_wine.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
# 5                 13.0                  40.0   0.9978  3.51       0.56
# 6                 15.0                  59.0   0.9964  3.30       0.46
# 7                 15.0                  21.0   0.9946  3.39       0.47
# 8                  9.0                  18.0   0.9968  3.36       0.57
# 9                 17.0                 102.0   0.9978  3.35       0.80
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5
# 5      9.4        5
# 6      9.4        5
# 7     10.0        7
# 8      9.5        7
# 9     10.5        5

# %%
white_wine = pd.read_csv("wine+quality\winequality-white.csv", sep= ';', delimiter=None) 
white_wine.describe()
#figure out what this really means
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# min       0.009000             2.000000              9.000000     0.987110
# 25%       0.036000            23.000000            108.000000     0.991723
# 50%       0.043000            34.000000            134.000000     0.993740
# 75%       0.050000            46.000000            167.000000     0.996100
# max       0.346000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  4898.000000  4898.000000  4898.000000  4898.000000
# mean      3.188267     0.489847    10.514267     5.877909
# std       0.151001     0.114126     1.230621     0.885639
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.090000     0.410000     9.500000     5.000000
# 50%       3.180000     0.470000    10.400000     6.000000
# 75%       3.280000     0.550000    11.400000     6.000000
# max       3.820000     1.080000    14.200000     9.000000

# %%
white_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 4         9.9        6
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [4898 rows x 12 columns]

# %%
white_wine.tail(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4888            6.8             0.220         0.36            1.20      0.052
# 4889            4.9             0.235         0.27           11.75      0.030
# 4890            6.1             0.340         0.29            2.20      0.036
# 4891            5.7             0.210         0.32            0.90      0.038
# 4892            6.5             0.230         0.38            1.30      0.032
# 4893            6.2             0.210         0.29            1.60      0.039
# 4894            6.6             0.320         0.36            8.00      0.047
# 4895            6.5             0.240         0.19            1.20      0.041
# 4896            5.5             0.290         0.30            1.10      0.022
# 4897            6.0             0.210         0.38            0.80      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 4888                 38.0                 127.0  0.99330  3.04       0.54
# 4889                 34.0                 118.0  0.99540  3.07       0.50
# 4890                 25.0                 100.0  0.98938  3.06       0.44
# 4891                 38.0                 121.0  0.99074  3.24       0.46
# 4892                 29.0                 112.0  0.99298  3.29       0.54
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 4888      9.2        5
# 4889      9.4        6
# 4890     11.8        6
# 4891     10.6        6
# 4892      9.7        5
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6

# %%
red_wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
print(red_wine.shape)
# Out:
# (1599, 12)

# %%
row, col = red_wine.shape
display(row)
display(col)
# Out:
# 1599
# 12

# %%
red_wine.isnull(). sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
red_wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
#make a copy of your original data
red_wine_01 = red_wine
red_wine_01.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
# 5                 13.0                  40.0   0.9978  3.51       0.56
# 6                 15.0                  59.0   0.9964  3.30       0.46
# 7                 15.0                  21.0   0.9946  3.39       0.47
# 8                  9.0                  18.0   0.9968  3.36       0.57
# 9                 17.0                 102.0   0.9978  3.35       0.80
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5
# 5      9.4        5
# 6      9.4        5
# 7     10.0        7
# 8      9.5        7
# 9     10.5        5

# %%
white_wine_01 = white_wine
white_wine_01.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
# 5            8.1              0.28         0.40             6.9      0.050
# 6            6.2              0.32         0.16             7.0      0.045
# 7            7.0              0.27         0.36            20.7      0.045
# 8            6.3              0.30         0.34             1.6      0.049
# 9            8.1              0.22         0.43             1.5      0.044
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
# 5                 30.0                  97.0   0.9951  3.26       0.44
# 6                 30.0                 136.0   0.9949  3.18       0.47
# 7                 45.0                 170.0   1.0010  3.00       0.45
# 8                 14.0                 132.0   0.9940  3.30       0.49
# 9                 28.0                 129.0   0.9938  3.22       0.45
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6
# 5     10.1        6
# 6      9.6        6
# 7      8.8        6
# 8      9.5        6
# 9     11.0        6

# %%
#creating a new column to rank the wine quality into three catergories 
red_wine_01['quality_label'] = red_wine_01['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')

#transform labels into categorical data type, instead of simple string 
red_wine_01['quality_label'] = pd.Categorical(red_wine_01['quality_label'], 
categories=['low', 'medium', 'high'])

#white wine
white_wine_01['quality_label'] = white_wine_01['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')
white_wine_01['quality_label'] = pd.Categorical(white_wine_01['quality_label'], 
categories=['low', 'medium', 'high'])

# %%
#trying out different groupings. different values for low medium high 
red_wine_01['quality_label'] = red_wine_01['quality'].apply(lambda value: 'low'
if value <= 4 else 'medium'
if value <= 6 else 'high')
red_wine_01['quality_label'] = pd.Categorical(red_wine_01['quality_label'], 
categories=['low', 'medium', 'high']) 

sns.histplot(x = 'quality_label', data= red_wine_01)
# Out:
# <Axes: xlabel='quality_label', ylabel='Count'>

# %%
#i dont like the way the data is split up, i dont think its very easy to look at or analyse 
#splitting it into three categories of low medium and high i a completely arbitratry way of doing things, i can also just gourp them in a different way 
#above or below average as a unit of measurement? 
#calculate the average quality given and use the mean as your comparison point 
#or better the median mid point of the range? 
#range is 3-8

# %%
sns.histplot(x = 'quality', data= red_wine_01)
# Out:
# <Axes: xlabel='quality', ylabel='Count'>

# %%
#using 5.5 as the median 

red_wine_01['quality_label'] = red_wine_01['quality'].apply(lambda value: 'below'
#if value <= 5 else 'medium'
if value <= 5.5 else 'above')
red_wine_01['quality_label'] = pd.Categorical(red_wine_01['quality_label'], 
categories=['below', 'above']) 

sns.histplot(x = 'quality_label', data= red_wine_01)
# Out:
# <Axes: xlabel='quality_label', ylabel='Count'>

# %%
#change colours in barplot 

#colour = ['light red' if x < 5.5 else 'light yellow' for x in red_wine_01]
#sns.barplot(x=df.xvar, y=df.yvar, palette=cols)
#sns.color_palette("pastel")
h1 = sns.histplot(x = 'quality_label', data= red_wine_01, fill=False)
h1.patches[0].set_facecolor('salmon')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#add title to bargraph 
sns.histplot(x = 'quality_label', data= red_wine_01).set(title='Average Red Wine Quality')
# Out:
# [Text(0.5, 1.0, 'Average Red Wine Quality')]

# %%
# define colour for each  
h2 = sns.histplot(x = 'quality_label', data= red_wine_01)
h2.patches[0].set_facecolor('indianred')
h2.patches[1].set_facecolor('darkred')
plt.xlabel("Quality Average - 5.5")
plt.ylabel("Count")
plt.title("Average Red Wine Quality")
#h2.annotate  to add annotations to plots 
plt.show
plt.savefig('h2.png', transparent=True)
#it says it works, but its still not showing as transparent

# %%
#add value numbers in barplot

# %%
# just for fun 
# calculate the mean of count below average

# %%
#how can i see how many are above the mean

# %%
pd.set_option('display.max_columns', None)
pd.concat([red_wine_01.describe(), white_wine_01.describe()], axis=1, keys=["Red Wines Stats", "White Wines Stats"])
# Out:
#       Red Wines Stats                                               \
#         fixed acidity volatile acidity  citric acid residual sugar
# count     1599.000000      1599.000000  1599.000000    1599.000000
# mean         8.319637         0.527821     0.270976       2.538806
# std          1.741096         0.179060     0.194801       1.409928
# min          4.600000         0.120000     0.000000       0.900000
# 25%          7.100000         0.390000     0.090000       1.900000
# 50%          7.900000         0.520000     0.260000       2.200000
# 75%          9.200000         0.640000     0.420000       2.600000
# max         15.900000         1.580000     1.000000      15.500000
#
#                                                                           \
#          chlorides free sulfur dioxide total sulfur dioxide      density
# count  1599.000000         1599.000000          1599.000000  1599.000000
# mean      0.087467           15.874922            46.467792     0.996747
# std       0.047065           10.460157            32.895324     0.001887
# min       0.012000            1.000000             6.000000     0.990070
# 25%       0.070000            7.000000            22.000000     0.995600
# 50%       0.079000           14.000000            38.000000     0.996750
# 75%       0.090000           21.000000            62.000000     0.997835
# max       0.611000           72.000000           289.000000     1.003690
#
#                                                           White Wines Stats  \
#                 pH    sulphates      alcohol      quality     fixed acidity
# count  1599.000000  1599.000000  1599.000000  1599.000000       4898.000000
# mean      3.311113     0.658149    10.422983     5.636023          6.854788
# std       0.154386     0.169507     1.065668     0.807569          0.843868
# min       2.740000     0.330000     8.400000     3.000000          3.800000
# 25%       3.210000     0.550000     9.500000     5.000000          6.300000
# 50%       3.310000     0.620000    10.200000     6.000000          6.800000
# 75%       3.400000     0.730000    11.100000     6.000000          7.300000
# max       4.010000     2.000000    14.900000     8.000000         14.200000
#
#                                                                  \
#       volatile acidity  citric acid residual sugar    chlorides
# count      4898.000000  4898.000000    4898.000000  4898.000000
# mean          0.278241     0.334192       6.391415     0.045772
# std           0.100795     0.121020       5.072058     0.021848
# min           0.080000     0.000000       0.600000     0.009000
# 25%           0.210000     0.270000       1.700000     0.036000
# 50%           0.260000     0.320000       5.200000     0.043000
# 75%           0.320000     0.390000       9.900000     0.050000
# max           1.100000     1.660000      65.800000     0.346000
#
#                                                                           \
#       free sulfur dioxide total sulfur dioxide      density           pH
# count         4898.000000          4898.000000  4898.000000  4898.000000
# mean            35.308085           138.360657     0.994027     3.188267
# std             17.007137            42.498065     0.002991     0.151001
# min              2.000000             9.000000     0.987110     2.720000
# 25%             23.000000           108.000000     0.991723     3.090000
# 50%             34.000000           134.000000     0.993740     3.180000
# 75%             46.000000           167.000000     0.996100     3.280000
# max            289.000000           440.000000     1.038980     3.820000
#
#
#          sulphates      alcohol      quality
# count  4898.000000  4898.000000  4898.000000
# mean      0.489847    10.514267     5.877909
# std       0.114126     1.230621     0.885639
# min       0.220000     8.000000     3.000000
# 25%       0.410000     9.500000     5.000000
# 50%       0.470000    10.400000     6.000000
# 75%       0.550000    11.400000     6.000000
# max       1.080000    14.200000     9.000000

# %%
#show findings, compare values, research attributes

# %%
#create a third data set bringing the two data sets together - combine data sets 
data = [red_wine_01, white_wine_01]
all_wine = pd.concat(data)
all_wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# min       0.009000             1.000000              6.000000     0.987110
# 25%       0.038000            17.000000             77.000000     0.992340
# 50%       0.047000            29.000000            118.000000     0.994890
# 75%       0.065000            41.000000            156.000000     0.996990
# max       0.611000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  6497.000000  6497.000000  6497.000000  6497.000000
# mean      3.218501     0.531268    10.491801     5.818378
# std       0.160787     0.148806     1.192712     0.873255
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.110000     0.430000     9.500000     5.000000
# 50%       3.210000     0.510000    10.300000     6.000000
# 75%       3.320000     0.600000    11.300000     6.000000
# max       4.010000     2.000000    14.900000     9.000000

# %%
#drop duplicates red wine 
red_wine.duplicated().sum()
red_wine_01.drop_duplicates(inplace=True)
red_wine_01.duplicated().sum()
print(red_wine_01.shape)
# Out:
# (1359, 13)

# %%
white_wine.duplicated().sum()
white_wine_01.drop_duplicates(inplace=True)
white_wine_01.duplicated().sum()
print(white_wine_01.shape)
# Out:
# (3961, 13)

# %%
red_quantity =1360
white_quantity = 3962

labels = ['Red Wine Count', 'White Wine Count']
sizes = [red_quantity, white_quantity]
colors = ['darkred', 'lightyellow']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.title('Red & White Wine Sample Size') 

#how to add count
# Out:
# Text(0.5, 1.0, 'Red & White Wine Sample Size')

# %%
#plot pie chart with actual values 
#values=df['your_column'].value_counts(dropna=True)
#plt.pie(<actual_values>, colors = colors, autopct= lambda x: '{:.0f}'.format(x*values.sum()/100), startangle=90)

# %%
#make a bar plot 
sns.histplot(x = 'quality', data= red_wine_01, binwidth= 1, fill=False)
#fill=False
# Out:
# <Axes: xlabel='quality', ylabel='Count'>

# %%
sns.histplot(x = 'pH', data= red_wine_01, hue='quality', element='poly')
# Out:
# <Axes: xlabel='pH', ylabel='Count'>

# %%
sns.histplot(x = 'volatile acidity', data= red_wine_01, hue='quality_label', element='poly')
#other editing options include 
#kde=True    give line 
#bins=[2,4,6,8]
#binwidth= 5
#binrange= (0,10)
#stat='probability'
# Out:
# <Axes: xlabel='volatile acidity', ylabel='Count'>

# %%
#low quality red wine seems to have high amounts of volatile acid. but only the 0.3 - 0.6 va range produces high quality red wine

# %%
sns.histplot(x = 'volatile acidity', data= white_wine_01, kde=True, hue='quality_label')
# Out:
# <Axes: xlabel='volatile acidity', ylabel='Count'>

# %%
white_wine_01.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'quality_label'],
#       dtype='object')

# %%
col_list_r = red_wine_01.columns
for columnname in col_list_r:
    print('this is the name of the column:', columnname)
    sns.boxplot(x = columnname, y = 'quality_label', data= red_wine_01)

    plt.show()
# Out:
# this is the name of the column: fixed acidity
# this is the name of the column: volatile acidity
# this is the name of the column: citric acid
# this is the name of the column: residual sugar
# this is the name of the column: chlorides
# this is the name of the column: free sulfur dioxide
# this is the name of the column: total sulfur dioxide
# this is the name of the column: density
# this is the name of the column: pH
# this is the name of the column: sulphates
# this is the name of the column: alcohol
# this is the name of the column: quality
# this is the name of the column: quality_label
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[119], line 4
#       2 for columnname in col_list_r:
#       3     print('this is the name of the column:', columnname)
# ----> 4     sns.boxplot(x = columnname, y = 'quality_label', data= red_wine_01)
#       6     plt.show()
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\seaborn\categorical.py:2231, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2224 def boxplot(
#    2225     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    2226     orient=None, color=None, palette=None, saturation=.75, width=.8,
#    2227     dodge=True, fliersize=5, linewidth=None, whis=1.5, ax=None,
#    2228     **kwargs
#    2229 ):
# -> 2231     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2232                           orient, color, palette, saturation,
#    2233                           width, dodge, fliersize, linewidth)
#    2235     if ax is None:
#    2236         ax = plt.gca()
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\seaborn\categorical.py:785, in _BoxPlotter.__init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth)
#     781 def __init__(self, x, y, hue, data, order, hue_order,
#     782              orient, color, palette, saturation,
#     783              width, dodge, fliersize, linewidth):
# --> 785     self.establish_variables(x, y, hue, data, orient, order, hue_order)
#     786     self.establish_colors(color, palette, saturation)
#     788     self.dodge = dodge
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\seaborn\categorical.py:544, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     541         raise ValueError(err)
#     543 # Figure out the plotting orientation
# --> 544 orient = infer_orient(
#     545     x, y, orient, require_numeric=self.require_numeric
#     546 )
#     548 # Option 2a:
#     549 # We are plotting a single set of data
#     550 # ------------------------------------
#     551 if x is None or y is None:
#     552
#     553     # Determine where the data are
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\seaborn\_oldcore.py:1632, in infer_orient(x, y, orient, require_numeric)
#    1630 elif require_numeric and "numeric" not in (x_type, y_type):
#    1631     err = "Neither the `x` nor `y` variable appears to be numeric."
# -> 1632     raise TypeError(err)
#    1634 else:
#    1635     return "v"
#
# TypeError: Neither the `x` nor `y` variable appears to be numeric.

# %%
col_list = white_wine_01.columns
for columnname in col_list:
    #print('this is the name of the column:', columnname)
    sns.boxplot(x = columnname, y = 'quality_label', data= white_wine_01)

    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[120], line 4
#       1 col_list = white_wine_01.columns
#       2 for columnname in col_list:
#       3     #print('this is the name of the column:', columnname)
# ----> 4     sns.boxplot(x = columnname, y = 'quality_label', data= white_wine_01)
#       6     plt.show()
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\seaborn\categorical.py:2231, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2224 def boxplot(
#    2225     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    2226     orient=None, color=None, palette=None, saturation=.75, width=.8,
#    2227     dodge=True, fliersize=5, linewidth=None, whis=1.5, ax=None,
#    2228     **kwargs
#    2229 ):
# -> 2231     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2232                           orient, color, palette, saturation,
#    2233                           width, dodge, fliersize, linewidth)
#    2235     if ax is None:
#    2236         ax = plt.gca()
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\seaborn\categorical.py:785, in _BoxPlotter.__init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth)
#     781 def __init__(self, x, y, hue, data, order, hue_order,
#     782              orient, color, palette, saturation,
#     783              width, dodge, fliersize, linewidth):
# --> 785     self.establish_variables(x, y, hue, data, orient, order, hue_order)
#     786     self.establish_colors(color, palette, saturation)
#     788     self.dodge = dodge
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\seaborn\categorical.py:544, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     541         raise ValueError(err)
#     543 # Figure out the plotting orientation
# --> 544 orient = infer_orient(
#     545     x, y, orient, require_numeric=self.require_numeric
#     546 )
#     548 # Option 2a:
#     549 # We are plotting a single set of data
#     550 # ------------------------------------
#     551 if x is None or y is None:
#     552
#     553     # Determine where the data are
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\seaborn\_oldcore.py:1632, in infer_orient(x, y, orient, require_numeric)
#    1630 elif require_numeric and "numeric" not in (x_type, y_type):
#    1631     err = "Neither the `x` nor `y` variable appears to be numeric."
# -> 1632     raise TypeError(err)
#    1634 else:
#    1635     return "v"
#
# TypeError: Neither the `x` nor `y` variable appears to be numeric.

# %%
#pairplot to show all scatterplot correlation 
#sns.pairplot(data=red_wine_01)
#vars='density', 'fixed acidity'
#google filter in pairplot
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[121], line 2
#       1 #pairplot to show all scatterplot correlation
# ----> 2 sns.pairplot(data=red_wine_01)
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\seaborn\axisgrid.py:2158, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2156 if kind == "scatter":
#    2157     from .relational import scatterplot  # Avoid circular import
# -> 2158     plotter(scatterplot, **plot_kws)
#    2159 elif kind == "reg":
#    2160     from .regression import regplot  # Avoid circular import
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\seaborn\axisgrid.py:1421, in PairGrid.map_offdiag(self, func, **kwargs)
#    1419     self.map_lower(func, **kwargs)
#    1420     if not self._corner:
# -> 1421         self.map_upper(func, **kwargs)
#    1422 else:
#    1423     indices = []
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\seaborn\axisgrid.py:1404, in PairGrid.map_upper(self, func, **kwargs)
#    1393 """Plot with a bivariate function on the upper diagonal subplots.
#    1394
#    1395 Parameters
#    (...)
#    1401
#    1402 """
#    1403 indices = zip(*np.triu_indices_from(self.axes, 1))
# -> 1404 self._map_bivariate(func, indices, **kwargs)
#    1405 return self
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\seaborn\axisgrid.py:1568, in PairGrid._map_bivariate(self, func, indices, **kwargs)
#    1566     if ax is None:  # i.e. we are in corner mode
#    1567         continue
# -> 1568     self._plot_bivariate(x_var, y_var, ax, func, **kws)
#    1569 self._add_axis_labels()
#    1571 if "hue" in signature(func).parameters:
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\seaborn\axisgrid.py:1609, in PairGrid._plot_bivariate(self, x_var, y_var, ax, func, **kwargs)
#    1605 if "hue" not in kwargs:
#    1606     kwargs.update({
#    1607         "hue": hue, "hue_order": self._hue_order, "palette": self._orig_palette,
#    1608     })
# -> 1609 func(x=x, y=y, **kwargs)
#    1611 self._update_legend_data(ax)
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\seaborn\relational.py:759, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     756 # Other functions have color as an explicit param,
#     757 # and we should probably do that here too
#     758 color = kwargs.pop("color", None)
# --> 759 kwargs["color"] = _default_color(ax.scatter, hue, color, kwargs)
#     761 p.plot(ax, kwargs)
#     763 return ax
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\seaborn\utils.py:122, in _default_color(method, hue, color, kws)
#     116 scout_size = max(
#     117     np.atleast_1d(kws.get(key, [])).shape[0]
#     118     for key in ["s", "c", "fc", "facecolor", "facecolors"]
#     119 )
#     120 scout_x = scout_y = np.full(scout_size, np.nan)
# --> 122 scout = method(scout_x, scout_y, **kws)
#     123 facecolors = scout.get_facecolors()
#     125 if not len(facecolors):
#     126     # Handle bug in matplotlib <= 3.2 (I think)
#     127     # This will limit the ability to use non color= kwargs to specify
#     128     # a color in versions of matplotlib with the bug, but trying to
#     129     # work out what the user wanted by re-implementing the broken logic
#     130     # of inspecting the kwargs is probably too brittle.
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\matplotlib\__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# -> 1442         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1444     bound = new_sig.bind(ax, *args, **kwargs)
#    1445     auto_label = (bound.arguments.get(label_namer)
#    1446                   or bound.kwargs.get(label_namer))
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:4711, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4708     if self._ymargin < 0.05 and x.size > 0:
#    4709         self.set_ymargin(0.05)
# -> 4711 self.add_collection(collection)
#    4712 self._request_autoscale_view()
#    4714 return collection
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\matplotlib\axes\_base.py:2264, in _AxesBase.add_collection(self, collection, autolim)
#    2260 if autolim:
#    2261     # Make sure viewLim is not stale (mostly to match
#    2262     # pre-lazy-autoscale behavior, which is not really better).
#    2263     self._unstale_viewLim()
# -> 2264     datalim = collection.get_datalim(self.transData)
#    2265     points = datalim.get_points()
#    2266     if not np.isinf(datalim.minpos).all():
#    2267         # By definition, if minpos (minimum positive value) is set
#    2268         # (i.e., non-inf), then min(points) <= minpos <= max(points),
#    2269         # and minpos would be superfluous. However, we add minpos to
#    2270         # the call so that self.dataLim will update its own minpos.
#    2271         # This ensures that log scales see the correct minimum.
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\matplotlib\collections.py:295, in Collection.get_datalim(self, transData)
#     293 offsets = (offset_trf - transData).transform(offsets)
#     294 # note A-B means A B^{-1}
# --> 295 offsets = np.ma.masked_invalid(offsets)
#     296 if not offsets.mask.all():
#     297     bbox = transforms.Bbox.null()
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\numpy\ma\core.py:2358, in masked_invalid(a, copy)
#    2331 def masked_invalid(a, copy=True):
#    2332     """
#    2333     Mask an array where invalid values occur (NaNs or infs).
#    2334
#    (...)
#    2356
#    2357     """
# -> 2358     a = np.array(a, copy=copy, subok=True)
#    2359     mask = getattr(a, '_mask', None)
#    2360     if mask is not None:
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\numpy\ma\core.py:3040, in MaskedArray.__array_finalize__(self, obj)
#    3037     else:
#    3038         order = "K"
# -> 3040     _mask = _mask.astype(_mask_dtype, order)
#    3041 else:
#    3042     # Take a view so shape changes, etc., do not propagate back.
#    3043     _mask = _mask.view()
#
# KeyboardInterrupt:
# Error in callback <function _draw_all_if_interactive at 0x0000020DEEAC5F30> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File c:\Users\lmyhe\anaconda3\lib\site-packages\matplotlib\pyplot.py:120, in _draw_all_if_interactive()
#     118 def _draw_all_if_interactive():
#     119     if matplotlib.is_interactive():
# --> 120         draw_all()
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\matplotlib\_pylab_helpers.py:132, in Gcf.draw_all(cls, force)
#     130 for manager in cls.get_all_fig_managers():
#     131     if force or manager.canvas.figure.stale:
# --> 132         manager.canvas.draw_idle()
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\matplotlib\backend_bases.py:2078, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    2076 if not self._is_idle_drawing:
#    2077     with self._idle_draw_cntx():
# -> 2078         self.draw(*args, **kwargs)
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:400, in FigureCanvasAgg.draw(self)
#     396 # Acquire a lock on the shared font cache.
#     397 with RendererAgg.lock, \
#     398      (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     399       else nullcontext()):
# --> 400     self.figure.draw(self.renderer)
#     401     # A GUI class may be need to update a window using this draw, so
#     402     # don't forget to call the superclass.
#     403     super().draw()
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\matplotlib\artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\matplotlib\figure.py:3125, in Figure.draw(self, renderer)
#    3122         # ValueError can occur when resizing a window.
#    3124 self.patch.draw(renderer)
# -> 3125 mimage._draw_list_compositing_images(
#    3126     renderer, self, artists, self.suppressComposite)
#    3128 for sfig in self.subfigs:
#    3129     sfig.draw(renderer)
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\matplotlib\image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\matplotlib\axes\_base.py:3030, in _AxesBase.draw(self, renderer)
#    3027     for spine in self.spines.values():
#    3028         artists.remove(spine)
# -> 3030 self._update_title_position(renderer)
#    3032 if not self.axison:
#    3033     for _axis in self._axis_map.values():
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\matplotlib\axes\_base.py:2965, in _AxesBase._update_title_position(self, renderer)
#    2962 bb = None
#    2963 if (ax.xaxis.get_ticks_position() in ['top', 'unknown']
#    2964         or ax.xaxis.get_label_position() == 'top'):
# -> 2965     bb = ax.xaxis.get_tightbbox(renderer)
#    2966 if bb is None:
#    2967     if 'outline' in ax.spines:
#    2968         # Special case for colorbars:
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\matplotlib\axis.py:1320, in Axis.get_tightbbox(self, renderer, for_layout_only)
#    1317     renderer = self.figure._get_renderer()
#    1318 ticks_to_draw = self._update_ticks()
# -> 1320 self._update_label_position(renderer)
#    1322 # go back to just this axis's tick labels
#    1323 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\matplotlib\axis.py:2308, in XAxis._update_label_position(self, renderer)
#    2304     return
#    2306 # get bounding boxes for this axis and any siblings
#    2307 # that have been set by `fig.align_xlabels()`
# -> 2308 bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    2310 x, y = self.label.get_position()
#    2311 if self.label_position == 'bottom':
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\matplotlib\axis.py:2103, in Axis._get_tick_boxes_siblings(self, renderer)
#    2101 for ax in grouper.get_siblings(self.axes):
#    2102     axis = getattr(ax, f"{axis_name}axis")
# -> 2103     ticks_to_draw = axis._update_ticks()
#    2104     tlb, tlb2 = axis._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    2105     bboxes.extend(tlb)
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\matplotlib\axis.py:1265, in Axis._update_ticks(self)
#    1263     tick.set_label1(label)
#    1264     tick.set_label2(label)
# -> 1265 minor_locs = self.get_minorticklocs()
#    1266 minor_labels = self.minor.formatter.format_ticks(minor_locs)
#    1267 minor_ticks = self.get_minor_ticks(len(minor_locs))
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\matplotlib\axis.py:1486, in Axis.get_minorticklocs(self)
#    1484 minor_locs = np.asarray(self.minor.locator())
#    1485 if self.remove_overlapping_locs:
# -> 1486     major_locs = self.major.locator()
#    1487     transform = self._scale.get_transform()
#    1488     tr_minor_locs = transform.transform(minor_locs)
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\matplotlib\ticker.py:2136, in MaxNLocator.__call__(self)
#    2134 def __call__(self):
#    2135     vmin, vmax = self.axis.get_view_interval()
# -> 2136     return self.tick_values(vmin, vmax)
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\matplotlib\ticker.py:2144, in MaxNLocator.tick_values(self, vmin, vmax)
#    2141     vmin = -vmax
#    2142 vmin, vmax = mtransforms.nonsingular(
#    2143     vmin, vmax, expander=1e-13, tiny=1e-14)
# -> 2144 locs = self._raw_ticks(vmin, vmax)
#    2146 prune = self._prune
#    2147 if prune == 'lower':
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\matplotlib\ticker.py:2083, in MaxNLocator._raw_ticks(self, vmin, vmax)
#    2081 if self._nbins == 'auto':
#    2082     if self.axis is not None:
# -> 2083         nbins = np.clip(self.axis.get_tick_space(),
#    2084                         max(1, self._min_n_ticks - 1), 9)
#    2085     else:
#    2086         nbins = 9
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\matplotlib\axis.py:2479, in XAxis.get_tick_space(self)
#    2478 def get_tick_space(self):
# -> 2479     ends = mtransforms.Bbox.unit().transformed(
#    2480         self.axes.transAxes - self.figure.dpi_scale_trans)
#    2481     length = ends.width * 72
#    2482     # There is a heuristic here that the aspect ratio of tick text
#    2483     # is no more than 3:1
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\matplotlib\transforms.py:479, in BboxBase.transformed(self, transform)
#     475 """
#     476 Construct a `Bbox` by statically transforming this one by *transform*.
#     477 """
#     478 pts = self.get_points()
# --> 479 ll, ul, lr = transform.transform(np.array(
#     480     [pts[0], [pts[0, 0], pts[1, 1]], [pts[1, 0], pts[0, 1]]]))
#     481 return Bbox([ll, [lr[0], ul[1]]])
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\matplotlib\transforms.py:1490, in Transform.transform(self, values)
#    1487 values = values.reshape((-1, self.input_dims))
#    1489 # Transform the values
# -> 1490 res = self.transform_affine(self.transform_non_affine(values))
#    1492 # Convert the result back to the shape of the input values.
#    1493 if ndim == 0:
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\matplotlib\transforms.py:2415, in CompositeGenericTransform.transform_affine(self, points)
#    2413 def transform_affine(self, points):
#    2414     # docstring inherited
# -> 2415     return self.get_affine().transform(points)
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\matplotlib\transforms.py:2441, in CompositeGenericTransform.get_affine(self)
#    2439     return self._b.get_affine()
#    2440 else:
# -> 2441     return Affine2D(np.dot(self._b.get_affine().get_matrix(),
#    2442                            self._a.get_affine().get_matrix()))
#
# File <__array_function__ internals>:180, in dot(*args, **kwargs)
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x0000020DEED65D80> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File c:\Users\lmyhe\anaconda3\lib\site-packages\matplotlib_inline\backend_inline.py:126, in flush_figures()
#     123 if InlineBackend.instance().close_figures:
#     124     # ignore the tracking, just draw and close all figures
#     125     try:
# --> 126         return show(True)
#     127     except Exception as e:
#     128         # safely show traceback if in IPython, else raise
#     129         ip = get_ipython()
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\matplotlib_inline\backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\IPython\core\display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\IPython\core\formatters.py:177, in DisplayFormatter.format(self, obj, include, exclude)
#     175 md = None
#     176 try:
# --> 177     data = formatter(obj)
#     178 except:
#     179     # FIXME: log the exception
#     180     raise
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\IPython\core\formatters.py:221, in catch_format_error(method, self, *args, **kwargs)
#     219 """show traceback on failed format call"""
#     220 try:
# --> 221     r = method(self, *args, **kwargs)
#     222 except NotImplementedError:
#     223     # don't warn on NotImplementedErrors
#     224     return self._check_return(None, args[0])
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\IPython\core\formatters.py:338, in BaseFormatter.__call__(self, obj)
#     336     pass
#     337 else:
# --> 338     return printer(obj)
#     339 # Finally look for special method names
#     340 method = get_real_method(obj, self.print_method)
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\matplotlib\backend_bases.py:2342, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2340 if bbox_inches:
#    2341     if bbox_inches == "tight":
# -> 2342         bbox_inches = self.figure.get_tightbbox(
#    2343             renderer, bbox_extra_artists=bbox_extra_artists)
#    2344         if pad_inches is None:
#    2345             pad_inches = rcParams['savefig.pad_inches']
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\matplotlib\figure.py:1731, in FigureBase.get_tightbbox(self, renderer, bbox_extra_artists)
#    1728     artists = bbox_extra_artists
#    1730 for a in artists:
# -> 1731     bbox = a.get_tightbbox(renderer)
#    1732     if bbox is not None:
#    1733         bb.append(bbox)
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\matplotlib\axes\_base.py:4390, in _AxesBase.get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4388         if ba:
#    4389             bb.append(ba)
# -> 4390 self._update_title_position(renderer)
#    4391 axbbox = self.get_window_extent(renderer)
#    4392 bb.append(axbbox)
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\matplotlib\axes\_base.py:2965, in _AxesBase._update_title_position(self, renderer)
#    2962 bb = None
#    2963 if (ax.xaxis.get_ticks_position() in ['top', 'unknown']
#    2964         or ax.xaxis.get_label_position() == 'top'):
# -> 2965     bb = ax.xaxis.get_tightbbox(renderer)
#    2966 if bb is None:
#    2967     if 'outline' in ax.spines:
#    2968         # Special case for colorbars:
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\matplotlib\axis.py:1320, in Axis.get_tightbbox(self, renderer, for_layout_only)
#    1317     renderer = self.figure._get_renderer()
#    1318 ticks_to_draw = self._update_ticks()
# -> 1320 self._update_label_position(renderer)
#    1322 # go back to just this axis's tick labels
#    1323 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\matplotlib\axis.py:2314, in XAxis._update_label_position(self, renderer)
#    2312 try:
#    2313     spine = self.axes.spines['bottom']
# -> 2314     spinebbox = spine.get_window_extent()
#    2315 except KeyError:
#    2316     # use Axes if spine doesn't exist
#    2317     spinebbox = self.axes.bbox
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\matplotlib\spines.py:154, in Spine.get_window_extent(self, renderer)
#     152 # make sure the location is updated so that transforms etc are correct:
#     153 self._adjust_location()
# --> 154 bb = super().get_window_extent(renderer=renderer)
#     155 if self.axis is None or not self.axis.get_visible():
#     156     return bb
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\matplotlib\patches.py:604, in Patch.get_window_extent(self, renderer)
#     603 def get_window_extent(self, renderer=None):
# --> 604     return self.get_path().get_extents(self.get_transform())
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\matplotlib\path.py:640, in Path.get_extents(self, transform, **kwargs)
#     638     xys = np.concatenate(xys)
#     639 if len(xys):
# --> 640     return Bbox([xys.min(axis=0), xys.max(axis=0)])
#     641 else:
#     642     return Bbox.null()
#
# File c:\Users\lmyhe\anaconda3\lib\site-packages\numpy\core\_methods.py:44, in _amin(a, axis, out, keepdims, initial, where)
#      42 def _amin(a, axis=None, out=None, keepdims=False,
#      43           initial=_NoValue, where=True):
# ---> 44     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#
# KeyboardInterrupt:

# %%
#col_list = white_wine_01.columns
#for columnname in col_list:
    #print('this is the name of the column:', columnname)
   # sns.histplot(x = columnname, data= white_wine_01, hue='quality_label', element='poly')

    #plt.show()

# %%
sns.histplot(x = columnname, data= white_wine_01, hue='quality_label', element='poly')

# %%
white_wine_01.columns

# %%
col_list_w = white_wine_01.columns
for columnname in col_list_w:
    print('this is the name of the column:', columnname)
    sns.histplot(x = columnname, data= white_wine_01, hue='quality_label', element='poly')

    plt.show()

# %%
t = white_wine_01.columns
for columnname in col_list:
    #print('this is the name of the column:', columnname)
    sns.histplot(x = columnname, data= white_wine_01, hue='quality_label', element='poly')

    plt.show()

# %%
sns.histplot(x = 'volatile acidity', data= white_wine_01, hue='quality_label', element='poly')

# %%
sns.histplot( y = 'alcohol', data=red_wine_01)

# %%
sns.boxplot(data=red_wine_01, x="quality", y="alcohol")
plt.title("Red Wine Quality")
# Out:
# Text(0.5, 1.0, 'Red Wine Quality')

# %%
#multivariate non-geographical correlation matrix?
#a correlation matrix is a tool to help you visualise and identify different strengths and weaknesses of correlation between two different features of a data set.

# %%
#looking at the correlation matrix 1 is the most positive correlation you can have. anything from 0.6 is a strong positive correlation 
# -1 ist the most negative correlation you can have. anything from -0.6 is a strong negative correlation and worth looking at. 
# positive correlation - both values going up or both vlaues going down 
# negative corrolation - something is added or decreased and the second variable acts in the opposite way. 
red_wine_01.corr().round(2)
#round to make it easier to read

# %%
sns.heatmap(red_wine_01.corr())
# Out:
# C:\Users\lmyhe\AppData\Local\Temp\ipykernel_3860\793896046.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(red_wine_01.corr())
# <Axes: >

# %%
sns.heatmap(red_wine_01.corr().round(2), annot=True, vmin=-1, vmax=1, center=0, cmap='vlag')
#annot=True shows the vlues in the individual heat map squares 
#add min and max values to determine range 
#cmap = colour maps from blue to red
# Out:
# C:\Users\lmyhe\AppData\Local\Temp\ipykernel_3860\2971597637.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(red_wine_01.corr().round(2), annot=True, vmin=-1, vmax=1, center=0, cmap='vlag')
# <Axes: >

# %%
#make the matrix visualisation easier
#take correlation matrix and assign it to a new variable
# mask our matrix using numpy 
matrix_red = red_wine_01.corr().round(2)
mask = np.triu(np.ones_like(matrix_red, dtype=bool))
mask
# Out:
# C:\Users\lmyhe\AppData\Local\Temp\ipykernel_3860\3501741227.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   matrix_red = red_wine_01.corr().round(2)
# array([[ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True],
#        [False,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True],
#        [False, False,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True],
#        [False, False, False,  True,  True,  True,  True,  True,  True,
#          True,  True,  True],
#        [False, False, False, False,  True,  True,  True,  True,  True,
#          True,  True,  True],
#        [False, False, False, False, False,  True,  True,  True,  True,
#          True,  True,  True],
#        [False, False, False, False, False, False,  True,  True,  True,
#          True,  True,  True],
#        [False, False, False, False, False, False, False,  True,  True,
#          True,  True,  True],
#        [False, False, False, False, False, False, False, False,  True,
#          True,  True,  True],
#        [False, False, False, False, False, False, False, False, False,
#          True,  True,  True],
#        [False, False, False, False, False, False, False, False, False,
#         False,  True,  True],
#        [False, False, False, False, False, False, False, False, False,
#         False, False,  True]])

# %%
sns.heatmap(matrix_red, annot=True, vmax=1, vmin=-1, cmap='vlag', mask=mask)
# Out:
# <Axes: >

# %%
matrix_red_01=matrix_red.unstack()
matrix_red_01[abs(matrix_red_01) >=0.60]
#not exactly sure what the absolute function shows. im guessing values from 0.6 in both directions.

# %% [markdown]
# Take away
# Red wine pre cleaning:
#
# Fixed acidity and pH = -0.68
# Fixed acidity and citric acid = 0.67
# Fixed acidity and density = 0.67 (most interesting, all the other ones seem logical to me)
# Total sulfur dioxide and free sulfur dioxide = 0.67

# %%
matrix_red_01[abs(matrix_red_01) <= -0.60]

# %%
#show only positive correlations 
matrix_red_01[matrix_red_01 >=0]

# %%
#show only negatives correlations 
matrix_red_01[matrix_red_01 <=0]
